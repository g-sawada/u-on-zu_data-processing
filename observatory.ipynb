# %%
#現在のディレクトリを確認
import os
current_directory = os.getcwd()
print("Current working directory:", current_directory)
# Out:
# Current working directory: /Users/sawad/dev/myapps/u-on-zu_data-processing

# %%
#出力先ディレクトリの設定
output_dir = './processed'

# %%
import pandas as pd

df=pd.read_csv('./raw/ame_master_20240401_utf-8.csv', encoding='utf-8')

display(df.head())
# Out:
#   都府県振興局  観測所番号 種類  観測所名     ｶﾀｶﾅ名 気象情報等に表記する名称                    所在地  緯度(度)  \
# 0     宗谷  11001  四   宗谷岬    ｿｳﾔﾐｻｷ       稚内市宗谷岬                 稚内市宗谷岬     45
# 1     宗谷  11016  官    稚内     ﾜｯｶﾅｲ        稚内市開運          稚内市開運　稚内地方気象台     45
# 2     宗谷  11046  四    礼文      ﾚﾌﾞﾝ        礼文町香深        礼文郡礼文町大字香深村トンナイ     45
# 3     宗谷  11061  官    声問      ｺｴﾄｲ         稚内空港  稚内市大字声問村字声問　稚内航空気象観測所     45
# 4     宗谷  11076  四  浜鬼志別  ﾊﾏｵﾆｼﾍﾞﾂ      猿払村浜鬼志別             宗谷郡猿払村浜鬼志別     45
#
#    緯度(分)  経度(度)  経度(分)  海面上の高さ(ｍ) 風速計の高さ(ｍ) 温度計の高さ(ｍ)    観測開始年月日    備考1  \
# 0   31.2    141   56.1         26      10.1       1.5  昭53.10.30      －
# 1   24.9    141   40.7          3      24.1         －   #昭50.4.1  11903
# 2   18.3    141    2.7         65       9.9       1.5  平15.10.17      －
# 3   24.2    141   48.1          8        10         －    平15.1.1  11904
# 4   20.1    142   10.2         13       9.9       1.5  昭53.10.30  11900
#
#            備考2
# 0            －
# 1            －
# 2            －
# 3  日照・湿度・気圧を除く
# 4            －

# %%
#全観測地テーブルの読み込みと結合 →　地上気象観測装置（略字「官」）
df_filt_kansyo = df[(df['種類'] == '官')| (df['種類'] == '四')]

display(df_filt_kansyo.head(30))

# df_filt_kansyo.to_csv(os.path.join(output_dir, 'observatories_kansyo.csv'), index=False)
# Out:
#    都府県振興局  観測所番号 種類  観測所名     ｶﾀｶﾅ名 気象情報等に表記する名称                      所在地  \
# 0      宗谷  11001  四   宗谷岬    ｿｳﾔﾐｻｷ       稚内市宗谷岬                   稚内市宗谷岬
# 1      宗谷  11016  官    稚内     ﾜｯｶﾅｲ        稚内市開運            稚内市開運　稚内地方気象台
# 2      宗谷  11046  四    礼文      ﾚﾌﾞﾝ        礼文町香深          礼文郡礼文町大字香深村トンナイ
# 3      宗谷  11061  官    声問      ｺｴﾄｲ         稚内空港    稚内市大字声問村字声問　稚内航空気象観測所
# 4      宗谷  11076  四  浜鬼志別  ﾊﾏｵﾆｼﾍﾞﾂ      猿払村浜鬼志別               宗谷郡猿払村浜鬼志別
# 5      宗谷  11091  官    本泊    ﾓﾄﾄﾞﾏﾘ         利尻空港  利尻郡利尻富士町鴛泊字本泊　利尻航空気象観測所
# 6      宗谷  11121  四    沼川      ﾇﾏｶﾜ        稚内市沼川                 稚内市声問村沼川
# 7      宗谷  11151  四    沓形     ｸﾂｶﾞﾀ        利尻町沓形               利尻郡利尻町沓形泉町
# 8      宗谷  11176  四    豊富      ﾄﾖﾄﾐ           豊富              天塩郡豊富町豊富東2条
# 9      宗谷  11206  四   浜頓別   ﾊﾏﾄﾝﾍﾞﾂ          浜頓別           枝幸郡浜頓別町クッチャロ湖畔
# 10     宗谷  11276  四   中頓別   ﾅｶﾄﾝﾍﾞﾂ          中頓別                枝幸郡中頓別町上駒
# 11     宗谷  11291  官  北見枝幸    ｷﾀﾐｴｻｼ        枝幸町枝幸   枝幸郡枝幸町本町　北見枝幸特別地域気象観測所
# 12     宗谷  11316  四    歌登    ｳﾀﾉﾎﾞﾘ        枝幸町歌登               枝幸郡枝幸町歌登東町
# 14     上川  12011  四    中川     ﾅｶｶﾞﾜ           中川                 中川郡中川町中川
# 15     上川  12041  四  音威子府   ｵﾄｲﾈｯﾌﾟ         音威子府             中川郡音威子府村音威子府
# 17     上川  12141  四    美深      ﾋﾞﾌｶ        美深町西町                 中川郡美深町西町
# 18     上川  12181  四    名寄       ﾅﾖﾛ        名寄市大橋                    名寄市大橋
# 20     上川  12231  四    下川      ｼﾓｶﾜ           下川                 上川郡下川町南町
# 22     上川  12261  四    士別      ｼﾍﾞﾂ      士別市九十九東                   士別市武徳町
# 23     上川  12266  四    朝日       ｱｻﾋ        士別市朝日                 士別市朝日町中央
# 24     上川  12301  四    和寒      ﾜｯｻﾑ           和寒                上川郡和寒町日ノ出
# 25     上川  12386  四   江丹別    ｴﾀﾝﾍﾞﾂ       旭川市江丹別                旭川市江丹別町芳野
# 26     上川  12396  四    比布     ﾋﾟｯﾌﾟ           比布                上川郡比布町北2線
# 27     上川  12411  四    上川      ｶﾐｶﾜ        上川町栄町                 上川郡上川町栄町
# 28     上川  12442  官    旭川     ｱｻﾋｶﾜ      旭川市宮前１条          旭川市宮前1条　旭川地方気象台
# 29     上川  12451  四    東川    ﾋｶﾞｼｶﾜ           東川                 上川郡東川町北町
# 32     上川  12501  官   東神楽  ﾋｶﾞｼｶｸﾞﾗ         旭川空港     上川郡東神楽町東2線　旭川航空気象観測所
# 33     上川  12512  四   志比内     ｼﾋﾞﾅｲ      東神楽町志比内               上川郡東神楽町志比内
# 34     上川  12551  四    美瑛      ﾋﾞｴｲ      美瑛町原野５線               上川郡美瑛町原野5線
# 35     上川  12596  四  上富良野     ｶﾐﾌﾗﾉ         上富良野               空知郡上富良野町大町
#
#     緯度(度)  緯度(分)  経度(度)  経度(分)  海面上の高さ(ｍ) 風速計の高さ(ｍ) 温度計の高さ(ｍ)  \
# 0      45   31.2    141   56.1         26      10.1       1.5
# 1      45   24.9    141   40.7          3      24.1         －
# 2      45   18.3    141    2.7         65       9.9       1.5
# 3      45   24.2    141   48.1          8        10         －
# 4      45   20.1    142   10.2         13       9.9       1.5
# 5      45   14.5    141   11.2         30        10         －
# 6      45   14.9    141   51.1         23        10       1.5
# 7      45   10.7    141    8.3         14       9.9       1.5
# 8      45    6.1    141   46.8         14        10       1.5
# 9      45    7.5    142   21.0         18        10       2.5
# 10     44   57.9    142   16.8         25      10.2       1.5
# 11     44   56.4    142   35.1          7      17.2         －
# 12     44   50.5    142   28.8         14        10       1.5
# 14     44   49.7    142    4.6         22        10       1.5
# 15     44   43.6    142   15.9         40       9.9       1.5
# 17     44   28.8    142   20.5         77        10       1.5
# 18     44   22.2    142   27.4         89       9.9       1.5
# 20     44   17.7    142   38.2        143        10       2.4
# 22     44   11.2    142   25.0        135         8       1.5
# 23     44    7.1    142   35.7        225        10       1.5
# 24     44    1.7    142   24.6        150        10       1.5
# 25     43   52.2    142   15.6        140        10       3.2
# 26     43   52.2    142   28.2        164        10       2.5
# 27     43   50.8    142   45.2        324        10       2.4
# 28     43   45.4    142   22.3        120        47         －
# 29     43   42.1    142   30.5        215        10       2.2
# 32     43   40.2    142   26.8        211        10         －
# 33     43   38.6    142   34.9        310        10       1.5
# 34     43   35.3    142   29.6        250        10       1.5
# 35     43   27.3    142   27.9        220        10       2.1
#
#                 観測開始年月日    備考1          備考2
# 0             昭53.10.30      －            －
# 1              #昭50.4.1  11903            －
# 2             平15.10.17      －            －
# 3               平15.1.1  11904  日照・湿度・気圧を除く
# 4             昭53.10.30  11900            －
# 5               平15.1.1      －  日照・湿度・気圧を除く
# 6             昭52.10.20  11905        湿度を除く
# 7            #昭52.10.24      －            －
# 8   (昭50.5.29)昭52.10.25  11910        湿度を除く
# 9            #昭52.10.19      －        湿度を除く
# 10  (昭50.5.28)昭52.10.19  11915        湿度を除く
# 11             #昭51.1.1  11917            －
# 12           #昭52.10.25  11920        湿度を除く
# 14            昭52.10.19      －        湿度を除く
# 15            昭52.10.17  12905            －
# 17            #昭52.10.6  12900        湿度を除く
# 18             #昭51.4.1  12910            －
# 20           #昭52.10.14  12925        湿度を除く
# 22           #昭52.10.13      －        湿度を除く
# 23            昭52.10.13      －        湿度を除く
# 24            昭52.10.12  12915        湿度を除く
# 25            昭52.10.11      －        湿度を除く
# 26  (昭50.5.27)昭52.10.11      －        湿度を除く
# 27           #昭52.10.12  12920        湿度を除く
# 28              平16.9.9  12927            －
# 29             昭52.10.5      －        湿度を除く
# 32              平15.1.1  12932  日照・湿度・気圧を除く
# 33              平4.10.9      －        湿度を除く
# 34   (昭50.5.28)昭52.10.6  12935        湿度を除く
# 35             昭52.10.8      －        湿度を除く

# %%
# 気象データと都府県振興局名が異なるものを揃えるために上書き
df_filt_kansyo.loc[df_filt_kansyo['都府県振興局'] == 'ｵﾎｰﾂｸ', '都府県振興局'] = '網走・北見・紋別'

# %%
# 「札幌市中央区北2条西　札幌管区気象台」と「札幌市中央区北2条西」のように，同じidで２個所の所在地データがあるものを1箇所に重複除外する（上にある行のデータを採用）
df_filt_kansyo_drop_duplicates = df_filt_kansyo.drop_duplicates(subset='観測所番号', keep='first')

display(df_filt_kansyo_drop_duplicates.head(100))

# df_filt_kansyo_drop_duplicates.to_csv(os.path.join(output_dir, 'observatories_kansyo_drop_duplicates.csv'), index=False)
# Out:
#        都府県振興局  観測所番号 種類  観測所名     ｶﾀｶﾅ名 気象情報等に表記する名称                    所在地  \
# 0          宗谷  11001  四   宗谷岬    ｿｳﾔﾐｻｷ       稚内市宗谷岬                 稚内市宗谷岬
# 1          宗谷  11016  官    稚内     ﾜｯｶﾅｲ        稚内市開運          稚内市開運　稚内地方気象台
# 2          宗谷  11046  四    礼文      ﾚﾌﾞﾝ        礼文町香深        礼文郡礼文町大字香深村トンナイ
# 3          宗谷  11061  官    声問      ｺｴﾄｲ         稚内空港  稚内市大字声問村字声問　稚内航空気象観測所
# 4          宗谷  11076  四  浜鬼志別  ﾊﾏｵﾆｼﾍﾞﾂ      猿払村浜鬼志別             宗谷郡猿払村浜鬼志別
# ..        ...    ... ..   ...       ...          ...                    ...
# 120  網走・北見・紋別  17596  四   留辺蘂    ﾙﾍﾞｼﾍﾞ      北見市留辺蘂町              北見市留辺蘂町大和
# 121  網走・北見・紋別  17607  四    境野      ｻｶｲﾉ        置戸町境野               常呂郡置戸町豊住
# 122  網走・北見・紋別  17631  四    美幌      ﾋﾞﾎﾛ           美幌               網走郡美幌町福住
# 125  網走・北見・紋別  17717  四    津別      ﾂﾍﾞﾂ        津別町豊永               網走郡津別町豊永
# 127        根室  18038  四    羅臼       ﾗｳｽ           羅臼               目梨郡羅臼町栄町
#
#      緯度(度)  緯度(分)  経度(度)  経度(分)  海面上の高さ(ｍ) 風速計の高さ(ｍ) 温度計の高さ(ｍ)     観測開始年月日  \
# 0       45   31.2    141   56.1         26      10.1       1.5   昭53.10.30
# 1       45   24.9    141   40.7          3      24.1         －    #昭50.4.1
# 2       45   18.3    141    2.7         65       9.9       1.5   平15.10.17
# 3       45   24.2    141   48.1          8        10         －     平15.1.1
# 4       45   20.1    142   10.2         13       9.9       1.5   昭53.10.30
# ..     ...    ...    ...    ...        ...       ...       ...         ...
# 120     43   44.5    143   27.0        325        10       2.5   #昭53.11.1
# 121     43   42.4    143   38.6        184        10       2.5   昭52.10.25
# 122     43   46.2    144   10.3         60      10.1       1.5  #昭52.10.20
# 125     43   42.1    144    2.0        100        10       2.5    昭63.10.4
# 127     44    1.4    145   11.2         15       9.9       1.5    平17.11.1
#
#        備考1          備考2
# 0        －            －
# 1    11903            －
# 2        －            －
# 3    11904  日照・湿度・気圧を除く
# 4    11900            －
# ..     ...          ...
# 120  17930        湿度を除く
# 121      －        湿度を除く
# 122      －        湿度を除く
# 125  17950        湿度を除く
# 127  18925            －
#
# [100 rows x 17 columns]

# %%
# 緯度・経度を60進数から10進数に変換したカラムを作成
df_add_lat_long = df_filt_kansyo_drop_duplicates.copy()

df_add_lat_long['latitude'] = df_add_lat_long['緯度(度)'] + (df_add_lat_long['緯度(分)']/60)
df_add_lat_long['longitude'] = df_add_lat_long['経度(度)'] + (df_add_lat_long['経度(分)']/60)

df_add_lat_long.to_csv(os.path.join(output_dir, 'observatories_finalize.csv'), index=False)

# %%
#######以下,pdf→excel変換したファイルを繰り返し処理で読み込んでいたボツ処理###########

#読み込みのテスト
import pandas as pd

df=pd.read_excel('./raw/list_of_observatories_240527DL.xlsx', sheet_name=3, skiprows=[1,2])

display(df.head())
# Out:
#                                            地域気象観測所一覧 Unnamed: 1  \
# 0  この「地域気象観測所一覧」は、アメダス観測所の観測所番号、種類および所在地等の情報を収録した...        NaN
# 1  １  観測所一覧は観測所を管理している気象台別に分け、さらに都、府、県、振興局別および観測所...        NaN
# 2                                                 略字    観測装置の種類
# 3                                                  四  有線ロボット気象計
# 4                                                  三  有線ロボット気象計
#
#                      Unnamed: 2 Unnamed: 3
# 0                           NaN        NaN
# 1                           NaN        NaN
# 2                    観  測  種  目     推計値の提供
# 3  降水量、気温、風向、風速、相対湿度（一部の観測所を除く）       日照時間
# 4                  降水量、気温、風向、風速          ―

# %%
#全観測地テーブルの読み込みと結合
import pandas as pd

sheets_to_read = list(range(3, 57))  # シート 4枚目〜57枚目

# シート毎に繰り返し読み込み。　　ヘッダー後の不要行（2〜3行目）はスキップ
dfs = [pd.read_excel('./raw/list_of_observatories_240527DL.xlsx', sheet_name=i, skiprows=[1,2]) for i in sheets_to_read]

# シートを結合。全体に対する新しいindexを付与
df_combined = pd.concat(dfs, ignore_index=True)

# display(df_combined)

# df_combined.to_excel(os.path.join(output_dir, 'combined_list_of_observatories.xlsx'), index=False, sheet_name='CombinedData')
# Out:
#      都府県\n振興局  観測所\n番号 種類  観測所名     ｶﾀｶﾅ名 気象情報等に表記する名称  \
# 0          宗谷    11001  四   宗谷岬    ｿｳﾔﾐｻｷ       稚内市宗谷岬
# 1          宗谷    11016  官    稚内     ﾜｯｶﾅｲ        稚内市開運
# 2          宗谷    11046  四    礼文      ﾚﾌﾞﾝ        礼文町香深
# 3          宗谷    11061  官    声問      ｺｴﾄｲ         稚内空港
# 4          宗谷    11076  四  浜鬼志別  ﾊﾏｵﾆｼﾍﾞﾂ      猿払村浜鬼志別
# ...       ...      ... ..   ...       ...          ...
# 1302       沖縄    93012  官   下地島    ｼﾓｼﾞｼﾏ        下地島空港
# 1303       沖縄    93041  官   宮古島    ﾐﾔｺｼﾞﾏ       宮古島市下里
# 1304       沖縄    93042  官    鏡原    ｶｶﾞﾐﾊﾗ         宮古空港
# 1305       沖縄    93051  雨    城辺    ｸﾞｽｸﾍﾞ       宮古島市新城
# 1306       沖縄    93062  官    仲筋     ﾅｶｽｼﾞ        多良間空港
#
#                           所在地  緯度  Unnamed: 8   経度  Unnamed: 10  海面上の\n高さ(ｍ)  \
# 0                      稚内市宗谷岬  45        31.2  141         56.1           26
# 1              稚内市開運  稚内地方気象台  45        24.9  141         40.7            3
# 2             礼文郡礼文町大字香深村トンナイ  45        18.3  141          2.7           65
# 3      稚内市大字声問村字声問  稚内航空気象観測所  45        24.2  141         48.1            8
# 4                  宗谷郡猿払村浜鬼志別  45        20.1  142         10.2           13
# ...                       ...  ..         ...  ...          ...          ...
# 1302  宮古島市伊良部字佐和田  下地島航空気象観測所  24        49.6  125          8.6            8
# 1303      宮古島市平良字下里  宮古島地方気象台  24        47.6  125         16.7           39
# 1304     宮古島市平良字下里  宮古航空気象観測所  24        46.9  125         17.7           43
# 1305                宮古島市城辺字新城  24        44.6  125         24.6           55
# 1306    宮古郡多良間村仲筋  多良間航空気象観測所  24        39.2  124         40.5           10
#
#      風速計の\n高さ(ｍ) 温度計の\n高さ(ｍ)    観測開始年月日    備考1          備考2
# 0           10.1         1.5  昭53.10.30      －            －
# 1           24.1           －   #昭50.4.1  11903            －
# 2            9.9         1.5  平15.10.17      －            －
# 3             10           －    平15.1.1  11904  日照・湿度・気圧を除く
# 4            9.9         1.5  昭53.10.30  11900            －
# ...          ...         ...        ...    ...          ...
# 1302          10           －    平15.1.1      －  日照・湿度・気圧を除く
# 1303        17.2           －   昭52.3.16      －            －
# 1304          10           －    平15.1.1      －  日照・湿度・気圧を除く
# 1305           －           －   昭53.1.30      －            －
# 1306          10           －    平15.1.1      －  日照・湿度・気圧を除く
#
# [1307 rows x 17 columns]

# %%
#全観測地テーブルの読み込みと結合 →　地上気象観測装置（略字「官」）
df_filt_kan = df_combined[df_combined['種類'] == '官']

display(df_filt_kan)

df_filt_kan.to_excel(os.path.join(output_dir, 'list_of_observatories.xlsx'), index=False, sheet_name='CombinedData')
# Out:
#      都府県\n振興局  観測所\n番号 種類  観測所名   ｶﾀｶﾅ名 気象情報等に表記する名称  \
# 1          宗谷    11016  官    稚内   ﾜｯｶﾅｲ        稚内市開運
# 3          宗谷    11061  官    声問    ｺｴﾄｲ         稚内空港
# 5          宗谷    11091  官    本泊  ﾓﾄﾄﾞﾏﾘ         利尻空港
# 11         宗谷    11291  官  北見枝幸  ｷﾀﾐｴｻｼ        枝幸町枝幸
# 28         上川    12442  官    旭川   ｱｻﾋｶﾜ      旭川市宮前１条
# ...       ...      ... ..   ...     ...          ...
# 1301       沖縄    92012  官    旧東   ｷｭｳﾄｳ        南大東空港
# 1302       沖縄    93012  官   下地島  ｼﾓｼﾞｼﾏ        下地島空港
# 1303       沖縄    93041  官   宮古島  ﾐﾔｺｼﾞﾏ       宮古島市下里
# 1304       沖縄    93042  官    鏡原  ｶｶﾞﾐﾊﾗ         宮古空港
# 1306       沖縄    93062  官    仲筋   ﾅｶｽｼﾞ        多良間空港
#
#                            所在地  緯度  Unnamed: 8   経度  Unnamed: 10  海面上の\n高さ(ｍ)  \
# 1               稚内市開運  稚内地方気象台  45        24.9  141         40.7            3
# 3       稚内市大字声問村字声問  稚内航空気象観測所  45        24.2  141         48.1            8
# 5     利尻郡利尻富士町鴛泊字本泊  利尻航空気象観測所  45        14.5  141         11.2           30
# 11     枝幸郡枝幸町本町  北見枝幸特別地域気象観測所  44        56.4  142         35.1            7
# 28            旭川市宮前1条  旭川地方気象台  43        45.4  142         22.3          120
# ...                        ...  ..         ...  ...          ...          ...
# 1301    島尻郡南大東村字旧東  南大東航空気象観測所  25        50.8  131         15.8           48
# 1302   宮古島市伊良部字佐和田  下地島航空気象観測所  24        49.6  125          8.6            8
# 1303       宮古島市平良字下里  宮古島地方気象台  24        47.6  125         16.7           39
# 1304      宮古島市平良字下里  宮古航空気象観測所  24        46.9  125         17.7           43
# 1306     宮古郡多良間村仲筋  多良間航空気象観測所  24        39.2  124         40.5           10
#
#      風速計の\n高さ(ｍ) 温度計の\n高さ(ｍ)   観測開始年月日    備考1          備考2
# 1           24.1           －  #昭50.4.1  11903            －
# 3             10           －   平15.1.1  11904  日照・湿度・気圧を除く
# 5             10           －   平15.1.1      －  日照・湿度・気圧を除く
# 11          17.2           －  #昭51.1.1  11917            －
# 28            47           －   平16.9.9  12927            －
# ...          ...         ...       ...    ...          ...
# 1301         9.8           －   平15.1.1      －  日照・湿度・気圧を除く
# 1302          10           －   平15.1.1      －  日照・湿度・気圧を除く
# 1303        17.2           －  昭52.3.16      －            －
# 1304          10           －   平15.1.1      －  日照・湿度・気圧を除く
# 1306          10           －   平15.1.1      －  日照・湿度・気圧を除く
#
# [253 rows x 17 columns]
